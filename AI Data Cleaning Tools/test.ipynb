# %%
import pandas as pd

# %%
pd.read_csv('../data/clean_csv/cjs-overview-tables-June-2024.ods_Q1_1.csv')
# Out:
#     Unnamed: 0                                           Category     2014  \
# 0            3            Out of court disposals (OOCDs) [note 6]   246665
# 1            4                OOCDs: penalty notices for disorder    72800
# 2            5                                    OOCDs: cautions   173865
# 3            6   OOCDs: cannabis / khat warnings [note 7][note 8]      [x]
# 4            7      OOCDs: community resolutions [note 8][note 9]      [x]
# 5            8  Defendants proceeded against total [note 5][no...  1438342
# 6            9  Defendants proceeded against: indictable offences   366456
# 7           10     Defendants proceeded against: summary offences  1071886
# 8           11     Defendants proceeded against: offences unknown        0
# 9           12        Offenders convicted total [note 5][note 10]  1185308
# 10          13           Offenders convicted: indictable offences   290802
# ...
